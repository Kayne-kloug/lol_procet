# %%
import pandas as pd
from pprint import pprint
import ast
import numpy as np

# %%
df = pd.read_csv('db__csv/ranked_game.csv', low_memory = False)

# %%
df.shape
# Out:
# (77111, 835)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'gameDuration', 'gameId', 'gameVersion', 'queueId',
#        'P1_teamId', 'P1_championId', 'P1_spell1Id', 'P1_spell2Id',
#        'P1_stats_participantId',
#        ...
#        'P8_goldPerMinDeltas_30-end', 'P8_damageTakenPerMinDeltas_30-end',
#        'P9_creepsPerMinDeltas_30-end', 'P9_xpPerMinDeltas_30-end',
#        'P9_goldPerMinDeltas_30-end', 'P9_damageTakenPerMinDeltas_30-end',
#        'P10_creepsPerMinDeltas_30-end', 'P10_xpPerMinDeltas_30-end',
#        'P10_goldPerMinDeltas_30-end', 'P10_damageTakenPerMinDeltas_30-end'],
#       dtype='object', length=835)

# %%
for i in range(df.shape[1]):
    print(df.columns[i])
# Out:
# Unnamed: 0
# gameDuration
# gameId
# gameVersion
# queueId
# P1_teamId
# P1_championId
# P1_spell1Id
# P1_spell2Id
# P1_stats_participantId
# P1_stats_win
# P1_stats_item0
# P1_stats_item1
# P1_stats_item2
# P1_stats_item3
# P1_stats_item4
# P1_stats_item5
# P1_stats_item6
# P1_stats_kills
# P1_stats_deaths
# P1_stats_assists
# P1_stats_largestKillingSpree
# P1_stats_largestMultiKill
# P1_stats_killingSprees
# P1_stats_longestTimeSpentLiving
# P1_stats_doubleKills
# P1_stats_tripleKills
# P1_stats_quadraKills
# P1_stats_pentaKills
# P1_stats_unrealKills
# P1_stats_totalDamageDealt
# P1_stats_magicDamageDealt
# P1_stats_physicalDamageDealt
# P1_stats_trueDamageDealt
# P1_stats_largestCriticalStrike
# P1_stats_totalDamageDealtToChampions
# P1_stats_magicDamageDealtToChampions
# P1_stats_physicalDamageDealtToChampions
# P1_stats_trueDamageDealtToChampions
# P1_stats_totalHeal
# P1_stats_totalUnitsHealed
# P1_stats_damageSelfMitigated
# P1_stats_damageDealtToObjectives
# ...

# %%
win_df = pd.read_csv('db__csv/ranked_win_game_edit.csv')
los_df = pd.read_csv('db__csv/ranked_lose_game_edit.csv')

# %%
win_df.isnull().sum()
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# teamId                  0
# win                     0
# firstBlood              0
# firstTower              0
# firstInhibitor          0
# firstBaron              0
# firstDragon             0
# firstRiftHerald         0
# towerKills              0
# inhibitorKills          0
# baronKills              0
# dragonKills             0
# vilemawKills            0
# riftHeraldKills         0
# dominionVictoryScore    0
# gameId                  0
# ban_champion_1          0
# ban_champion_2          0
# ban_champion_3          0
# ban_champion_4          0
# ban_champion_5          0
# dtype: int64

# %%
los_df.isnull().sum()
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# teamId                  0
# win                     0
# firstBlood              0
# firstTower              0
# firstInhibitor          0
# firstBaron              0
# firstDragon             0
# firstRiftHerald         0
# towerKills              0
# inhibitorKills          0
# baronKills              0
# dragonKills             0
# vilemawKills            0
# riftHeraldKills         0
# dominionVictoryScore    0
# gameId                  0
# ban_champion_1          0
# ban_champion_2          0
# ban_champion_3          0
# ban_champion_4          0
# ban_champion_5          0
# dtype: int64
